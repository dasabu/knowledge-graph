# %%
import csv
import os
from dotenv import load_dotenv

from neo4j import GraphDatabase

# %%
load_dotenv()

NEO4J_URI = os.getenv('NEO4J_URI_LOCAL')
NEO4J_USERNAME = os.getenv('NEO4J_USERNAME_LOCAL')
NEO4J_PASSWORD = os.getenv('NEO4J_PASSWORD_LOCAL')

# %%
# Connect and run cypher query
def execute_query(driver, cypher_query, parameters=None):
    try:
        with driver.session() as session:
            result = session.run(cypher_query, parameters)
    except Exception as e:
        print(f"Error executing query: {e}")
        return None

# %% [markdown]
# ### Define Entities and Relationships
#
# **Entities:**
# - Healthcare Provider
# - Patient
# - Specialization
# - Location
#
# **Relationships:**
# - TREATS
# - SPECIALIZES_IN
# - LOCATED_AT

# %%
def create_healthcare_provider_node(driver, provider, bio):
    print(f'Creating healthcare provider node...')
    print(f'- Provider: {provider}')
    print(f'- Bio: {bio}')
    
    cypher_query = '''
    MERGE (hp:HealthcareProvider {name: $provider, bio: $bio})
    '''
    
    parameters = {
        'provider': provider,
        'bio': bio
    }
    
    execute_query(driver, cypher_query, parameters)

def create_patient_node(driver, patient, patient_age, patient_gender, patient_condition):
    print(f'Creating patient node...')
    print(f'- Patient: {patient}')
    print(f'- Age: {patient_age}')
    print(f'- Gender: {patient_gender}')
    print(f'- Condition: {patient_condition}')
    
    cypher_query = '''
    MERGE (p:Patient {name: $patient, age: $patient_age, gender: $patient_gender, condition: $patient_condition})
    '''
    
    parameters = {
        'patient': patient,
        'patient_age': patient_age,
        'patient_gender': patient_gender,
        'patient_condition': patient_condition
    }
    
    execute_query(driver, cypher_query, parameters)

def create_specialization_node(driver, specialization):
    print(f'Creating specialization node...')
    print(f'- Specialization: {specialization}')
    
    cypher_query = '''
    MERGE (s:Specialization {name: $specialization})
    '''
    
    parameters = {'specialization': specialization}
    
    execute_query(driver, cypher_query, parameters)

def create_location_node(driver, location):
    print(f'Creating location node...')
    print(f'- Location: {location}')
    
    cypher_query = '''
    MERGE (l:Location {name: $location})
    '''
    
    parameters = {'location': location}
    
    execute_query(driver, cypher_query, parameters)

# %%
def create_relationships(driver, provider, patient, specialization, location):
    print(f'---- Creating relationships ----')
    print(f'\tProvider: {provider}')
    print(f'\tPatient: {patient}')
    print(f'\tSpecialization: {specialization}')
    print(f'\tLocation: {location}')
    print('---------------------------------')
    
    cypher_query = '''
    MATCH (hp:HealthcareProvider {name: $provider}), (p:Patient {name: $patient})
    MERGE (hp)-[:TREATS]->(p)
    WITH hp
    MATCH (hp), (s:Specialization {name: $specialization})
    MERGE (hp)-[:SPECIALIZES_IN]->(s)
    WITH hp
    MATCH (hp), (l:Location {name: $location})
    MERGE (hp)-[:LOCATED_AT]->(l)
    '''
    
    parameters = {
        'patient': patient,
        'provider': provider,
        'specialization': specialization,
        'location': location
    }
    
    execute_query(driver, cypher_query, parameters)

# %%
# Read CSV file and populate the graph
def read_csv_and_populate_graph(driver, csv_file_path):
    with open(csv_file_path, 'r') as file:
        reader = csv.DictReader(file)
        print(f'Reading CSV file {csv_file_path}. Start populating graph...')
        
        for row in reader:
            provider = row['Provider']
            patient = row['Patient']
            specialization = row['Specialization']
            location = row['Location']
            bio = row['Bio']
            patient_age = row['Patient_Age']
            patient_gender = row['Patient_Gender']
            patient_condition = row['Patient_Condition']
            
            # Create nodes
            create_healthcare_provider_node(driver, provider, bio)
            create_patient_node(driver, patient, patient_age, patient_gender, patient_condition)
            create_specialization_node(driver, specialization)
            create_location_node(driver, location)
            
            # Create relationships
            create_relationships(driver, provider, patient, specialization, location)
        
    driver.close()
    print(f'Finished populating graph!')

# %%
# Initialize Neo4j driver
driver = GraphDatabase.driver(
    uri=NEO4J_URI, 
    auth=(NEO4J_USERNAME, NEO4J_PASSWORD)
)
csv_file_path = 'healthcare.csv'

read_csv_and_populate_graph(driver, csv_file_path)
# Out:
# Reading CSV file healthcare.csv. Start populating graph...
# Creating healthcare provider node...
# - Provider: Dr. Jessica Lee
# - Bio: Dr. Jessica Lee is a dermatologist focused on skin cancer treatment and prevention.
# Creating patient node...
# - Patient: Eva Blue
# - Age: 66
# - Gender: Male
# - Condition: Asthma
# Creating specialization node...
# - Specialization: Pediatrics
# Creating location node...
# - Location: Los Angeles
# ---- Creating relationships ----
# 	Provider: Dr. Jessica Lee
# 	Patient: Eva Blue
# 	Specialization: Pediatrics
# 	Location: Los Angeles
# ---------------------------------
# Creating healthcare provider node...
# - Provider: Dr. Michael Brown
# - Bio: Dr. Michael Brown is an orthopedic surgeon with expertise in joint replacement.
# Creating patient node...
# - Patient: Alice Brown
# - Age: 59
# - Gender: Female
# - Condition: Osteoarthritis
# Creating specialization node...
# - Specialization: Pediatrics
# Creating location node...
# - Location: Los Angeles
# ---- Creating relationships ----
# 	Provider: Dr. Michael Brown
# 	Patient: Alice Brown
# 	Specialization: Pediatrics
# 	Location: Los Angeles
# ---------------------------------
# Creating healthcare provider node...
# - Provider: Dr. Jessica Lee
# - Bio: Dr. Jessica Lee is a dermatologist focused on skin cancer treatment and prevention.
# Creating patient node...
# - Patient: Grace Red
# - Age: 72
# - Gender: Male
# - Condition: Eczema
# Creating specialization node...
# - Specialization: Pediatrics
# Creating location node...
# - Location: New York
# ---- Creating relationships ----
# 	Provider: Dr. Jessica Lee
# 	Patient: Grace Red
# 	Specialization: Pediatrics
# 	Location: New York
# ---------------------------------
# Creating healthcare provider node...
# - Provider: Dr. Emily Davis
# - Bio: Dr. Emily Davis specializes in neurology and has published numerous research papers.
# Creating patient node...
# - Patient: Frank Yellow
# - Age: 78
# - Gender: Female
# - Condition: Epilepsy
# Creating specialization node...
# - Specialization: Pediatrics
# Creating location node...
# - Location: New York
# ---- Creating relationships ----
# 	Provider: Dr. Emily Davis
# 	Patient: Frank Yellow
# 	Specialization: Pediatrics
# 	Location: New York
# ---------------------------------
# Creating healthcare provider node...
# - Provider: Dr. John Smith
# - Bio: Dr. John Smith is a renowned cardiologist with over 20 years of experience.
# Creating patient node...
# - Patient: David Black
# - Age: 32
# - Gender: Female
# - Condition: Hypertension
# Creating specialization node...
# - Specialization: Cardiology
# Creating location node...
# - Location: Los Angeles
# ---- Creating relationships ----
# 	Provider: Dr. John Smith
# 	Patient: David Black
# 	Specialization: Cardiology
# 	Location: Los Angeles
# ---------------------------------
# Creating healthcare provider node...
# - Provider: Dr. Jessica Lee
# - Bio: Dr. Jessica Lee is a dermatologist focused on skin cancer treatment and prevention.
# Creating patient node...
# - Patient: Bob White
# - Age: 99
# - Gender: Female
# - Condition: Psoriasis
# Creating specialization node...
# - Specialization: Pediatrics
# Creating location node...
# - Location: Phoenix
# ---- Creating relationships ----
# 	Provider: Dr. Jessica Lee
# 	Patient: Bob White
# 	Specialization: Pediatrics
# 	Location: Phoenix
# ---------------------------------
# Creating healthcare provider node...
# - Provider: Dr. Sarah Johnson
# - Bio: Dr. Sarah Johnson is a pediatrician known for her compassionate care.
# Creating patient node...
# - Patient: Grace Red
# - Age: 90
# - Gender: Male
# - Condition: Acne
# Creating specialization node...
# - Specialization: Dermatology
# Creating location node...
# - Location: Houston
# ---- Creating relationships ----
# 	Provider: Dr. Sarah Johnson
# 	Patient: Grace Red
# 	Specialization: Dermatology
# 	Location: Houston
# ---------------------------------
# Creating healthcare provider node...
# - Provider: Dr. Sarah Johnson
# - Bio: Dr. Sarah Johnson is a pediatrician known for her compassionate care.
# Creating patient node...
# - Patient: Grace Red
# - Age: 54
# - Gender: Male
# - Condition: ADHD
# Creating specialization node...
# - Specialization: Pediatrics
# Creating location node...
# - Location: Phoenix
# ---- Creating relationships ----
# 	Provider: Dr. Sarah Johnson
# 	Patient: Grace Red
# 	Specialization: Pediatrics
# 	Location: Phoenix
# ---------------------------------
# Creating healthcare provider node...
# - Provider: Dr. John Smith
# - Bio: Dr. John Smith is a renowned cardiologist with over 20 years of experience.
# Creating patient node...
# - Patient: Frank Yellow
# - Age: 11
# - Gender: Female
# - Condition: Scoliosis
# Creating specialization node...
# - Specialization: Orthopedics
# Creating location node...
# - Location: New York
# ---- Creating relationships ----
# 	Provider: Dr. John Smith
# 	Patient: Frank Yellow
# 	Specialization: Orthopedics
# 	Location: New York
# ---------------------------------
# Creating healthcare provider node...
# - Provider: Dr. John Smith
# - Bio: Dr. John Smith is a renowned cardiologist with over 20 years of experience.
# Creating patient node...
# - Patient: Frank Yellow
# - Age: 2
# - Gender: Female
# - Condition: Heart Murmur
# Creating specialization node...
# - Specialization: Cardiology
# Creating location node...
# - Location: New York
# ---- Creating relationships ----
# 	Provider: Dr. John Smith
# 	Patient: Frank Yellow
# 	Specialization: Cardiology
# 	Location: New York
# ---------------------------------
# Creating healthcare provider node...
# - Provider: Dr. Emily Davis
# - Bio: Dr. Emily Davis specializes in neurology and has published numerous research papers.
# Creating patient node...
# - Patient: Grace Red
# - Age: 16
# - Gender: Female
# - Condition: Back Pain
# Creating specialization node...
# - Specialization: Orthopedics
# Creating location node...
# - Location: New York
# ---- Creating relationships ----
# 	Provider: Dr. Emily Davis
# 	Patient: Grace Red
# 	Specialization: Orthopedics
# 	Location: New York
# ---------------------------------
# Creating healthcare provider node...
# - Provider: Dr. John Smith
# - Bio: Dr. John Smith is a renowned cardiologist with over 20 years of experience.
# Creating patient node...
# - Patient: David Black
# - Age: 76
# - Gender: Female
# - Condition: Asthma
# Creating specialization node...
# - Specialization: Pediatrics
# Creating location node...
# - Location: Los Angeles
# ---- Creating relationships ----
# 	Provider: Dr. John Smith
# 	Patient: David Black
# 	Specialization: Pediatrics
# 	Location: Los Angeles
# ---------------------------------
# Creating healthcare provider node...
# - Provider: Dr. Jessica Lee
# - Bio: Dr. Jessica Lee is a dermatologist focused on skin cancer treatment and prevention.
# Creating patient node...
# - Patient: Alice Brown
# - Age: 38
# - Gender: Female
# - Condition: Migraine
# Creating specialization node...
# - Specialization: Neurology
# Creating location node...
# - Location: New York
# ---- Creating relationships ----
# 	Provider: Dr. Jessica Lee
# 	Patient: Alice Brown
# 	Specialization: Neurology
# 	Location: New York
# ---------------------------------
# Creating healthcare provider node...
# - Provider: Dr. Emily Davis
# - Bio: Dr. Emily Davis specializes in neurology and has published numerous research papers.
# Creating patient node...
# - Patient: Grace Red
# - Age: 54
# - Gender: Male
# - Condition: Rosacea
# Creating specialization node...
# - Specialization: Dermatology
# Creating location node...
# - Location: Chicago
# ---- Creating relationships ----
# 	Provider: Dr. Emily Davis
# 	Patient: Grace Red
# 	Specialization: Dermatology
# 	Location: Chicago
# ---------------------------------
# Creating healthcare provider node...
# - Provider: Dr. Jessica Lee
# - Bio: Dr. Jessica Lee is a dermatologist focused on skin cancer treatment and prevention.
# Creating patient node...
# - Patient: Frank Yellow
# - Age: 16
# - Gender: Male
# - Condition: Hypertension
# Creating specialization node...
# - Specialization: Cardiology
# Creating location node...
# - Location: Phoenix
# ---- Creating relationships ----
# 	Provider: Dr. Jessica Lee
# 	Patient: Frank Yellow
# 	Specialization: Cardiology
# 	Location: Phoenix
# ---------------------------------
# Creating healthcare provider node...
# - Provider: Dr. Emily Davis
# - Bio: Dr. Emily Davis specializes in neurology and has published numerous research papers.
# Creating patient node...
# - Patient: Eva Blue
# - Age: 52
# - Gender: Male
# - Condition: Arthritis
# Creating specialization node...
# - Specialization: Orthopedics
# Creating location node...
# - Location: Chicago
# ---- Creating relationships ----
# 	Provider: Dr. Emily Davis
# 	Patient: Eva Blue
# 	Specialization: Orthopedics
# 	Location: Chicago
# ---------------------------------
# Creating healthcare provider node...
# - Provider: Dr. Jessica Lee
# - Bio: Dr. Jessica Lee is a dermatologist focused on skin cancer treatment and prevention.
# Creating patient node...
# - Patient: Bob White
# - Age: 86
# - Gender: Female
# - Condition: Psoriasis
# Creating specialization node...
# - Specialization: Dermatology
# Creating location node...
# - Location: New York
# ---- Creating relationships ----
# 	Provider: Dr. Jessica Lee
# 	Patient: Bob White
# 	Specialization: Dermatology
# 	Location: New York
# ---------------------------------
# Creating healthcare provider node...
# - Provider: Dr. John Smith
# - Bio: Dr. John Smith is a renowned cardiologist with over 20 years of experience.
# Creating patient node...
# - Patient: Alice Brown
# - Age: 4
# - Gender: Female
# - Condition: Congenital Heart Disease
# Creating specialization node...
# - Specialization: Cardiology
# Creating location node...
# - Location: New York
# ---- Creating relationships ----
# 	Provider: Dr. John Smith
# 	Patient: Alice Brown
# 	Specialization: Cardiology
# 	Location: New York
# ---------------------------------
# Creating healthcare provider node...
# - Provider: Dr. John Smith
# - Bio: Dr. John Smith is a renowned cardiologist with over 20 years of experience.
# Creating patient node...
# - Patient: Frank Yellow
# - Age: 51
# - Gender: Male
# - Condition: Coronary Artery Disease
# Creating specialization node...
# - Specialization: Cardiology
# Creating location node...
# - Location: Phoenix
# ---- Creating relationships ----
# 	Provider: Dr. John Smith
# 	Patient: Frank Yellow
# 	Specialization: Cardiology
# 	Location: Phoenix
# ---------------------------------
# Creating healthcare provider node...
# - Provider: Dr. Emily Davis
# - Bio: Dr. Emily Davis specializes in neurology and has published numerous research papers.
# Creating patient node...
# - Patient: Charlie Green
# - Age: 49
# - Gender: Female
# - Condition: ADHD
# Creating specialization node...
# - Specialization: Pediatrics
# Creating location node...
# - Location: Phoenix
# ---- Creating relationships ----
# 	Provider: Dr. Emily Davis
# 	Patient: Charlie Green
# 	Specialization: Pediatrics
# 	Location: Phoenix
# ---------------------------------
# Creating healthcare provider node...
# - Provider: Dr. Jessica Lee
# - Bio: Dr. Jessica Lee is a dermatologist focused on skin cancer treatment and prevention.
# Creating patient node...
# - Patient: Frank Yellow
# - Age: 27
# - Gender: Female
# - Condition: Fracture
# Creating specialization node...
# - Specialization: Orthopedics
# Creating location node...
# - Location: New York
# ---- Creating relationships ----
# 	Provider: Dr. Jessica Lee
# 	Patient: Frank Yellow
# 	Specialization: Orthopedics
# 	Location: New York
# ---------------------------------
# Creating healthcare provider node...
# - Provider: Dr. Jessica Lee
# - Bio: Dr. Jessica Lee is a dermatologist focused on skin cancer treatment and prevention.
# Creating patient node...
# - Patient: Bob White
# - Age: 73
# - Gender: Male
# - Condition: Osteoporosis
# Creating specialization node...
# - Specialization: Orthopedics
# Creating location node...
# - Location: Los Angeles
# ---- Creating relationships ----
# 	Provider: Dr. Jessica Lee
# 	Patient: Bob White
# 	Specialization: Orthopedics
# 	Location: Los Angeles
# ---------------------------------
# Creating healthcare provider node...
# - Provider: Dr. Jessica Lee
# - Bio: Dr. Jessica Lee is a dermatologist focused on skin cancer treatment and prevention.
# Creating patient node...
# - Patient: David Black
# - Age: 87
# - Gender: Female
# - Condition: Asthma
# Creating specialization node...
# - Specialization: Pediatrics
# Creating location node...
# - Location: Phoenix
# ---- Creating relationships ----
# 	Provider: Dr. Jessica Lee
# 	Patient: David Black
# 	Specialization: Pediatrics
# 	Location: Phoenix
# ---------------------------------
# Creating healthcare provider node...
# - Provider: Dr. Sarah Johnson
# - Bio: Dr. Sarah Johnson is a pediatrician known for her compassionate care.
# Creating patient node...
# - Patient: Bob White
# - Age: 53
# - Gender: Female
# - Condition: ADHD
# Creating specialization node...
# - Specialization: Pediatrics
# Creating location node...
# - Location: New York
# ---- Creating relationships ----
# 	Provider: Dr. Sarah Johnson
# 	Patient: Bob White
# 	Specialization: Pediatrics
# 	Location: New York
# ---------------------------------
# Creating healthcare provider node...
# - Provider: Dr. John Smith
# - Bio: Dr. John Smith is a renowned cardiologist with over 20 years of experience.
# Creating patient node...
# - Patient: Alice Brown
# - Age: 36
# - Gender: Male
# - Condition: Hypertension
# Creating specialization node...
# - Specialization: Cardiology
# Creating location node...
# - Location: Los Angeles
# ---- Creating relationships ----
# 	Provider: Dr. John Smith
# 	Patient: Alice Brown
# 	Specialization: Cardiology
# 	Location: Los Angeles
# ---------------------------------
# Creating healthcare provider node...
# - Provider: Dr. Sarah Johnson
# - Bio: Dr. Sarah Johnson is a pediatrician known for her compassionate care.
# Creating patient node...
# - Patient: David Black
# - Age: 84
# - Gender: Male
# - Condition: Arrhythmia
# Creating specialization node...
# - Specialization: Cardiology
# Creating location node...
# - Location: Houston
# ---- Creating relationships ----
# 	Provider: Dr. Sarah Johnson
# 	Patient: David Black
# 	Specialization: Cardiology
# 	Location: Houston
# ---------------------------------
# Creating healthcare provider node...
# - Provider: Dr. Michael Brown
# - Bio: Dr. Michael Brown is an orthopedic surgeon with expertise in joint replacement.
# Creating patient node...
# - Patient: Bob White
# - Age: 70
# - Gender: Male
# - Condition: Parkinson's Disease
# Creating specialization node...
# - Specialization: Neurology
# Creating location node...
# - Location: New York
# ---- Creating relationships ----
# 	Provider: Dr. Michael Brown
# 	Patient: Bob White
# 	Specialization: Neurology
# 	Location: New York
# ---------------------------------
# Creating healthcare provider node...
# - Provider: Dr. Sarah Johnson
# - Bio: Dr. Sarah Johnson is a pediatrician known for her compassionate care.
# Creating patient node...
# - Patient: Charlie Green
# - Age: 6
# - Gender: Male
# - Condition: Epilepsy
# Creating specialization node...
# - Specialization: Neurology
# Creating location node...
# - Location: Los Angeles
# ---- Creating relationships ----
# 	Provider: Dr. Sarah Johnson
# 	Patient: Charlie Green
# 	Specialization: Neurology
# 	Location: Los Angeles
# ---------------------------------
# Creating healthcare provider node...
# - Provider: Dr. Sarah Johnson
# - Bio: Dr. Sarah Johnson is a pediatrician known for her compassionate care.
# Creating patient node...
# - Patient: Eva Blue
# - Age: 38
# - Gender: Female
# - Condition: Heart Disease
# Creating specialization node...
# - Specialization: Cardiology
# Creating location node...
# - Location: Los Angeles
# ---- Creating relationships ----
# 	Provider: Dr. Sarah Johnson
# 	Patient: Eva Blue
# 	Specialization: Cardiology
# 	Location: Los Angeles
# ---------------------------------
# Creating healthcare provider node...
# - Provider: Dr. Jessica Lee
# - Bio: Dr. Jessica Lee is a dermatologist focused on skin cancer treatment and prevention.
# Creating patient node...
# - Patient: Frank Yellow
# - Age: 94
# - Gender: Male
# - Condition: Stroke
# Creating specialization node...
# - Specialization: Neurology
# Creating location node...
# - Location: Houston
# ---- Creating relationships ----
# 	Provider: Dr. Jessica Lee
# 	Patient: Frank Yellow
# 	Specialization: Neurology
# 	Location: Houston
# ---------------------------------
# Creating healthcare provider node...
# - Provider: Dr. Jessica Lee
# - Bio: Dr. Jessica Lee is a dermatologist focused on skin cancer treatment and prevention.
# Creating patient node...
# - Patient: Charlie Green
# - Age: 47
# - Gender: Male
# - Condition: Eczema
# Creating specialization node...
# - Specialization: Dermatology
# Creating location node...
# - Location: Los Angeles
# ---- Creating relationships ----
# 	Provider: Dr. Jessica Lee
# 	Patient: Charlie Green
# 	Specialization: Dermatology
# 	Location: Los Angeles
# ---------------------------------
# Creating healthcare provider node...
# - Provider: Dr. Jessica Lee
# - Bio: Dr. Jessica Lee is a dermatologist focused on skin cancer treatment and prevention.
# Creating patient node...
# - Patient: Frank Yellow
# - Age: 21
# - Gender: Female
# - Condition: Heart Failure
# Creating specialization node...
# - Specialization: Cardiology
# Creating location node...
# - Location: New York
# ---- Creating relationships ----
# 	Provider: Dr. Jessica Lee
# 	Patient: Frank Yellow
# 	Specialization: Cardiology
# 	Location: New York
# ---------------------------------
# Creating healthcare provider node...
# - Provider: Dr. Jessica Lee
# - Bio: Dr. Jessica Lee is a dermatologist focused on skin cancer treatment and prevention.
# Creating patient node...
# - Patient: Frank Yellow
# - Age: 95
# - Gender: Male
# - Condition: Coronary Artery Disease
# Creating specialization node...
# - Specialization: Cardiology
# Creating location node...
# - Location: Chicago
# ---- Creating relationships ----
# 	Provider: Dr. Jessica Lee
# 	Patient: Frank Yellow
# 	Specialization: Cardiology
# 	Location: Chicago
# ---------------------------------
# Creating healthcare provider node...
# - Provider: Dr. Michael Brown
# - Bio: Dr. Michael Brown is an orthopedic surgeon with expertise in joint replacement.
# Creating patient node...
# - Patient: Frank Yellow
# - Age: 19
# - Gender: Male
# - Condition: Migraine
# Creating specialization node...
# - Specialization: Neurology
# Creating location node...
# - Location: Chicago
# ---- Creating relationships ----
# 	Provider: Dr. Michael Brown
# 	Patient: Frank Yellow
# 	Specialization: Neurology
# 	Location: Chicago
# ---------------------------------
# Creating healthcare provider node...
# - Provider: Dr. Sarah Johnson
# - Bio: Dr. Sarah Johnson is a pediatrician known for her compassionate care.
# Creating patient node...
# - Patient: Frank Yellow
# - Age: 57
# - Gender: Male
# - Condition: Arthritis
# Creating specialization node...
# - Specialization: Orthopedics
# Creating location node...
# - Location: Los Angeles
# ---- Creating relationships ----
# 	Provider: Dr. Sarah Johnson
# 	Patient: Frank Yellow
# 	Specialization: Orthopedics
# 	Location: Los Angeles
# ---------------------------------
# Creating healthcare provider node...
# - Provider: Dr. Michael Brown
# - Bio: Dr. Michael Brown is an orthopedic surgeon with expertise in joint replacement.
# Creating patient node...
# - Patient: Frank Yellow
# - Age: 63
# - Gender: Female
# - Condition: Osteoporosis
# Creating specialization node...
# - Specialization: Orthopedics
# Creating location node...
# - Location: New York
# ---- Creating relationships ----
# 	Provider: Dr. Michael Brown
# 	Patient: Frank Yellow
# 	Specialization: Orthopedics
# 	Location: New York
# ---------------------------------
# Creating healthcare provider node...
# - Provider: Dr. Jessica Lee
# - Bio: Dr. Jessica Lee is a dermatologist focused on skin cancer treatment and prevention.
# Creating patient node...
# - Patient: David Black
# - Age: 23
# - Gender: Female
# - Condition: Scoliosis
# Creating specialization node...
# - Specialization: Orthopedics
# Creating location node...
# - Location: Houston
# ---- Creating relationships ----
# 	Provider: Dr. Jessica Lee
# 	Patient: David Black
# 	Specialization: Orthopedics
# 	Location: Houston
# ---------------------------------
# Creating healthcare provider node...
# - Provider: Dr. Emily Davis
# - Bio: Dr. Emily Davis specializes in neurology and has published numerous research papers.
# Creating patient node...
# - Patient: Eva Blue
# - Age: 89
# - Gender: Male
# - Condition: Back Pain
# Creating specialization node...
# - Specialization: Orthopedics
# Creating location node...
# - Location: Chicago
# ---- Creating relationships ----
# 	Provider: Dr. Emily Davis
# 	Patient: Eva Blue
# 	Specialization: Orthopedics
# 	Location: Chicago
# ---------------------------------
# Creating healthcare provider node...
# - Provider: Dr. Michael Brown
# - Bio: Dr. Michael Brown is an orthopedic surgeon with expertise in joint replacement.
# Creating patient node...
# - Patient: David Black
# - Age: 28
# - Gender: Female
# - Condition: Heart Disease
# Creating specialization node...
# - Specialization: Cardiology
# Creating location node...
# - Location: Chicago
# ---- Creating relationships ----
# 	Provider: Dr. Michael Brown
# 	Patient: David Black
# 	Specialization: Cardiology
# 	Location: Chicago
# ---------------------------------
# Creating healthcare provider node...
# - Provider: Dr. Jessica Lee
# - Bio: Dr. Jessica Lee is a dermatologist focused on skin cancer treatment and prevention.
# Creating patient node...
# - Patient: Grace Red
# - Age: 18
# - Gender: Female
# - Condition: Stroke
# Creating specialization node...
# - Specialization: Neurology
# Creating location node...
# - Location: New York
# ---- Creating relationships ----
# 	Provider: Dr. Jessica Lee
# 	Patient: Grace Red
# 	Specialization: Neurology
# 	Location: New York
# ---------------------------------
# Creating healthcare provider node...
# - Provider: Dr. Sarah Johnson
# - Bio: Dr. Sarah Johnson is a pediatrician known for her compassionate care.
# Creating patient node...
# - Patient: Alice Brown
# - Age: 20
# - Gender: Male
# - Condition: Acne
# Creating specialization node...
# - Specialization: Dermatology
# Creating location node...
# - Location: Phoenix
# ---- Creating relationships ----
# 	Provider: Dr. Sarah Johnson
# 	Patient: Alice Brown
# 	Specialization: Dermatology
# 	Location: Phoenix
# ---------------------------------
# Creating healthcare provider node...
# - Provider: Dr. Jessica Lee
# - Bio: Dr. Jessica Lee is a dermatologist focused on skin cancer treatment and prevention.
# Creating patient node...
# - Patient: David Black
# - Age: 95
# - Gender: Male
# - Condition: Parkinson's Disease
# Creating specialization node...
# - Specialization: Neurology
# Creating location node...
# - Location: Phoenix
# ---- Creating relationships ----
# 	Provider: Dr. Jessica Lee
# 	Patient: David Black
# 	Specialization: Neurology
# 	Location: Phoenix
# ---------------------------------
# Creating healthcare provider node...
# - Provider: Dr. Michael Brown
# - Bio: Dr. Michael Brown is an orthopedic surgeon with expertise in joint replacement.
# Creating patient node...
# - Patient: Alice Brown
# - Age: 17
# - Gender: Male
# - Condition: Hypertension
# Creating specialization node...
# - Specialization: Cardiology
# Creating location node...
# - Location: Los Angeles
# ---- Creating relationships ----
# 	Provider: Dr. Michael Brown
# 	Patient: Alice Brown
# 	Specialization: Cardiology
# 	Location: Los Angeles
# ---------------------------------
# Creating healthcare provider node...
# - Provider: Dr. Emily Davis
# - Bio: Dr. Emily Davis specializes in neurology and has published numerous research papers.
# Creating patient node...
# - Patient: David Black
# - Age: 26
# - Gender: Male
# - Condition: Fracture
# Creating specialization node...
# - Specialization: Orthopedics
# Creating location node...
# - Location: Phoenix
# ---- Creating relationships ----
# 	Provider: Dr. Emily Davis
# 	Patient: David Black
# 	Specialization: Orthopedics
# 	Location: Phoenix
# ---------------------------------
# Creating healthcare provider node...
# - Provider: Dr. Jessica Lee
# - Bio: Dr. Jessica Lee is a dermatologist focused on skin cancer treatment and prevention.
# Creating patient node...
# - Patient: Alice Brown
# - Age: 11
# - Gender: Female
# - Condition: Heart Murmur
# Creating specialization node...
# - Specialization: Cardiology
# Creating location node...
# - Location: Chicago
# ---- Creating relationships ----
# 	Provider: Dr. Jessica Lee
# 	Patient: Alice Brown
# 	Specialization: Cardiology
# 	Location: Chicago
# ---------------------------------
# Creating healthcare provider node...
# - Provider: Dr. Emily Davis
# - Bio: Dr. Emily Davis specializes in neurology and has published numerous research papers.
# Creating patient node...
# - Patient: Grace Red
# - Age: 24
# - Gender: Female
# - Condition: Rosacea
# Creating specialization node...
# - Specialization: Dermatology
# Creating location node...
# - Location: Los Angeles
# ---- Creating relationships ----
# 	Provider: Dr. Emily Davis
# 	Patient: Grace Red
# 	Specialization: Dermatology
# 	Location: Los Angeles
# ---------------------------------
# Creating healthcare provider node...
# - Provider: Dr. Michael Brown
# - Bio: Dr. Michael Brown is an orthopedic surgeon with expertise in joint replacement.
# Creating patient node...
# - Patient: David Black
# - Age: 54
# - Gender: Female
# - Condition: Arrhythmia
# Creating specialization node...
# - Specialization: Cardiology
# Creating location node...
# - Location: Los Angeles
# ---- Creating relationships ----
# 	Provider: Dr. Michael Brown
# 	Patient: David Black
# 	Specialization: Cardiology
# 	Location: Los Angeles
# ---------------------------------
# Creating healthcare provider node...
# - Provider: Dr. John Smith
# - Bio: Dr. John Smith is a renowned cardiologist with over 20 years of experience.
# Creating patient node...
# - Patient: Eva Blue
# - Age: 6
# - Gender: Female
# - Condition: Eczema
# Creating specialization node...
# - Specialization: Dermatology
# Creating location node...
# - Location: Chicago
# ---- Creating relationships ----
# 	Provider: Dr. John Smith
# 	Patient: Eva Blue
# 	Specialization: Dermatology
# 	Location: Chicago
# ---------------------------------
# Creating healthcare provider node...
# - Provider: Dr. John Smith
# - Bio: Dr. John Smith is a renowned cardiologist with over 20 years of experience.
# Creating patient node...
# - Patient: Alice Brown
# - Age: 42
# - Gender: Female
# - Condition: Asthma
# Creating specialization node...
# - Specialization: Pediatrics
# Creating location node...
# - Location: Phoenix
# ---- Creating relationships ----
# 	Provider: Dr. John Smith
# 	Patient: Alice Brown
# 	Specialization: Pediatrics
# 	Location: Phoenix
# ---------------------------------
# Creating healthcare provider node...
# - Provider: Dr. Jessica Lee
# - Bio: Dr. Jessica Lee is a dermatologist focused on skin cancer treatment and prevention.
# Creating patient node...
# - Patient: Alice Brown
# - Age: 85
# - Gender: Female
# - Condition: Heart Disease
# Creating specialization node...
# - Specialization: Cardiology
# Creating location node...
# - Location: Phoenix
# ---- Creating relationships ----
# 	Provider: Dr. Jessica Lee
# 	Patient: Alice Brown
# 	Specialization: Cardiology
# 	Location: Phoenix
# ---------------------------------
# Creating healthcare provider node...
# - Provider: Dr. Jessica Lee
# - Bio: Dr. Jessica Lee is a dermatologist focused on skin cancer treatment and prevention.
# Creating patient node...
# - Patient: David Black
# - Age: 9
# - Gender: Male
# - Condition: Epilepsy
# Creating specialization node...
# - Specialization: Neurology
# Creating location node...
# - Location: New York
# ---- Creating relationships ----
# 	Provider: Dr. Jessica Lee
# 	Patient: David Black
# 	Specialization: Neurology
# 	Location: New York
# ---------------------------------
# Creating healthcare provider node...
# - Provider: Dr. Michael Brown
# - Bio: Dr. Michael Brown is an orthopedic surgeon with expertise in joint replacement.
# Creating patient node...
# - Patient: Frank Yellow
# - Age: 45
# - Gender: Male
# - Condition: Coronary Artery Disease
# Creating specialization node...
# - Specialization: Cardiology
# Creating location node...
# - Location: Houston
# ---- Creating relationships ----
# 	Provider: Dr. Michael Brown
# 	Patient: Frank Yellow
# 	Specialization: Cardiology
# 	Location: Houston
# ---------------------------------
# Creating healthcare provider node...
# - Provider: Dr. Sarah Johnson
# - Bio: Dr. Sarah Johnson is a pediatrician known for her compassionate care.
# Creating patient node...
# - Patient: Frank Yellow
# - Age: 54
# - Gender: Male
# - Condition: ADHD
# Creating specialization node...
# - Specialization: Pediatrics
# Creating location node...
# - Location: Houston
# ---- Creating relationships ----
# 	Provider: Dr. Sarah Johnson
# 	Patient: Frank Yellow
# 	Specialization: Pediatrics
# 	Location: Houston
# ---------------------------------
# Creating healthcare provider node...
# - Provider: Dr. Jessica Lee
# - Bio: Dr. Jessica Lee is a dermatologist focused on skin cancer treatment and prevention.
# Creating patient node...
# - Patient: Alice Brown
# - Age: 93
# - Gender: Male
# - Condition: Parkinson's Disease
# Creating specialization node...
# - Specialization: Neurology
# Creating location node...
# - Location: New York
# ---- Creating relationships ----
# 	Provider: Dr. Jessica Lee
# 	Patient: Alice Brown
# 	Specialization: Neurology
# 	Location: New York
# ---------------------------------
# Creating healthcare provider node...
# - Provider: Dr. John Smith
# - Bio: Dr. John Smith is a renowned cardiologist with over 20 years of experience.
# Creating patient node...
# - Patient: Frank Yellow
# - Age: 84
# - Gender: Male
# - Condition: Stroke
# Creating specialization node...
# - Specialization: Neurology
# Creating location node...
# - Location: Chicago
# ---- Creating relationships ----
# 	Provider: Dr. John Smith
# 	Patient: Frank Yellow
# 	Specialization: Neurology
# 	Location: Chicago
# ---------------------------------
# Creating healthcare provider node...
# - Provider: Dr. Michael Brown
# - Bio: Dr. Michael Brown is an orthopedic surgeon with expertise in joint replacement.
# Creating patient node...
# - Patient: Bob White
# - Age: 4
# - Gender: Female
# - Condition: Asthma
# Creating specialization node...
# - Specialization: Pediatrics
# Creating location node...
# - Location: Chicago
# ---- Creating relationships ----
# 	Provider: Dr. Michael Brown
# 	Patient: Bob White
# 	Specialization: Pediatrics
# 	Location: Chicago
# ---------------------------------
# Creating healthcare provider node...
# - Provider: Dr. John Smith
# - Bio: Dr. John Smith is a renowned cardiologist with over 20 years of experience.
# Creating patient node...
# - Patient: David Black
# - Age: 49
# - Gender: Male
# - Condition: Hypertension
# Creating specialization node...
# - Specialization: Cardiology
# Creating location node...
# - Location: New York
# ---- Creating relationships ----
# 	Provider: Dr. John Smith
# 	Patient: David Black
# 	Specialization: Cardiology
# 	Location: New York
# ---------------------------------
# Creating healthcare provider node...
# - Provider: Dr. John Smith
# - Bio: Dr. John Smith is a renowned cardiologist with over 20 years of experience.
# Creating patient node...
# - Patient: Frank Yellow
# - Age: 81
# - Gender: Male
# - Condition: Heart Failure
# Creating specialization node...
# - Specialization: Cardiology
# Creating location node...
# - Location: Los Angeles
# ---- Creating relationships ----
# 	Provider: Dr. John Smith
# 	Patient: Frank Yellow
# 	Specialization: Cardiology
# 	Location: Los Angeles
# ---------------------------------
# Creating healthcare provider node...
# - Provider: Dr. Jessica Lee
# - Bio: Dr. Jessica Lee is a dermatologist focused on skin cancer treatment and prevention.
# Creating patient node...
# - Patient: Bob White
# - Age: 3
# - Gender: Female
# - Condition: Fracture
# Creating specialization node...
# - Specialization: Orthopedics
# Creating location node...
# - Location: Phoenix
# ---- Creating relationships ----
# 	Provider: Dr. Jessica Lee
# 	Patient: Bob White
# 	Specialization: Orthopedics
# 	Location: Phoenix
# ---------------------------------
# Creating healthcare provider node...
# - Provider: Dr. Jessica Lee
# - Bio: Dr. Jessica Lee is a dermatologist focused on skin cancer treatment and prevention.
# Creating patient node...
# - Patient: Eva Blue
# - Age: 86
# - Gender: Female
# - Condition: Coronary Artery Disease
# Creating specialization node...
# - Specialization: Cardiology
# Creating location node...
# - Location: Phoenix
# ---- Creating relationships ----
# 	Provider: Dr. Jessica Lee
# 	Patient: Eva Blue
# 	Specialization: Cardiology
# 	Location: Phoenix
# ---------------------------------
# Creating healthcare provider node...
# - Provider: Dr. Sarah Johnson
# - Bio: Dr. Sarah Johnson is a pediatrician known for her compassionate care.
# Creating patient node...
# - Patient: Eva Blue
# - Age: 57
# - Gender: Male
# - Condition: Epilepsy
# Creating specialization node...
# - Specialization: Neurology
# Creating location node...
# - Location: Phoenix
# ---- Creating relationships ----
# 	Provider: Dr. Sarah Johnson
# 	Patient: Eva Blue
# 	Specialization: Neurology
# 	Location: Phoenix
# ---------------------------------
# Creating healthcare provider node...
# - Provider: Dr. Jessica Lee
# - Bio: Dr. Jessica Lee is a dermatologist focused on skin cancer treatment and prevention.
# Creating patient node...
# - Patient: Bob White
# - Age: 30
# - Gender: Male
# - Condition: Parkinson's Disease
# Creating specialization node...
# - Specialization: Neurology
# Creating location node...
# - Location: Los Angeles
# ---- Creating relationships ----
# 	Provider: Dr. Jessica Lee
# 	Patient: Bob White
# 	Specialization: Neurology
# 	Location: Los Angeles
# ---------------------------------
# Creating healthcare provider node...
# - Provider: Dr. Emily Davis
# - Bio: Dr. Emily Davis specializes in neurology and has published numerous research papers.
# Creating patient node...
# - Patient: Charlie Green
# - Age: 13
# - Gender: Female
# - Condition: Epilepsy
# Creating specialization node...
# - Specialization: Neurology
# Creating location node...
# - Location: Houston
# ---- Creating relationships ----
# 	Provider: Dr. Emily Davis
# 	Patient: Charlie Green
# 	Specialization: Neurology
# 	Location: Houston
# ---------------------------------
# Creating healthcare provider node...
# - Provider: Dr. Sarah Johnson
# - Bio: Dr. Sarah Johnson is a pediatrician known for her compassionate care.
# Creating patient node...
# - Patient: Eva Blue
# - Age: 16
# - Gender: Female
# - Condition: Acne
# Creating specialization node...
# - Specialization: Dermatology
# Creating location node...
# - Location: Houston
# ---- Creating relationships ----
# 	Provider: Dr. Sarah Johnson
# 	Patient: Eva Blue
# 	Specialization: Dermatology
# 	Location: Houston
# ---------------------------------
# Creating healthcare provider node...
# - Provider: Dr. Emily Davis
# - Bio: Dr. Emily Davis specializes in neurology and has published numerous research papers.
# Creating patient node...
# - Patient: Grace Red
# - Age: 59
# - Gender: Male
# - Condition: Heart Disease
# Creating specialization node...
# - Specialization: Cardiology
# Creating location node...
# - Location: Chicago
# ---- Creating relationships ----
# 	Provider: Dr. Emily Davis
# 	Patient: Grace Red
# 	Specialization: Cardiology
# 	Location: Chicago
# ---------------------------------
# Creating healthcare provider node...
# - Provider: Dr. John Smith
# - Bio: Dr. John Smith is a renowned cardiologist with over 20 years of experience.
# Creating patient node...
# - Patient: Bob White
# - Age: 91
# - Gender: Female
# - Condition: Asthma
# Creating specialization node...
# - Specialization: Pediatrics
# Creating location node...
# - Location: Houston
# ---- Creating relationships ----
# 	Provider: Dr. John Smith
# 	Patient: Bob White
# 	Specialization: Pediatrics
# 	Location: Houston
# ---------------------------------
# Creating healthcare provider node...
# - Provider: Dr. Emily Davis
# - Bio: Dr. Emily Davis specializes in neurology and has published numerous research papers.
# Creating patient node...
# - Patient: Grace Red
# - Age: 4
# - Gender: Male
# - Condition: Epilepsy
# Creating specialization node...
# - Specialization: Neurology
# Creating location node...
# - Location: Phoenix
# ---- Creating relationships ----
# 	Provider: Dr. Emily Davis
# 	Patient: Grace Red
# 	Specialization: Neurology
# 	Location: Phoenix
# ---------------------------------
# Creating healthcare provider node...
# - Provider: Dr. Michael Brown
# - Bio: Dr. Michael Brown is an orthopedic surgeon with expertise in joint replacement.
# Creating patient node...
# - Patient: Frank Yellow
# - Age: 54
# - Gender: Female
# - Condition: Migraine
# Creating specialization node...
# - Specialization: Neurology
# Creating location node...
# - Location: New York
# ---- Creating relationships ----
# 	Provider: Dr. Michael Brown
# 	Patient: Frank Yellow
# 	Specialization: Neurology
# 	Location: New York
# ---------------------------------
# Creating healthcare provider node...
# - Provider: Dr. Sarah Johnson
# - Bio: Dr. Sarah Johnson is a pediatrician known for her compassionate care.
# Creating patient node...
# - Patient: David Black
# - Age: 72
# - Gender: Male
# - Condition: Parkinson's Disease
# Creating specialization node...
# - Specialization: Neurology
# Creating location node...
# - Location: Chicago
# ---- Creating relationships ----
# 	Provider: Dr. Sarah Johnson
# 	Patient: David Black
# 	Specialization: Neurology
# 	Location: Chicago
# ---------------------------------
# Creating healthcare provider node...
# - Provider: Dr. John Smith
# - Bio: Dr. John Smith is a renowned cardiologist with over 20 years of experience.
# Creating patient node...
# - Patient: Grace Red
# - Age: 44
# - Gender: Male
# - Condition: Eczema
# Creating specialization node...
# - Specialization: Dermatology
# Creating location node...
# - Location: Houston
# ---- Creating relationships ----
# 	Provider: Dr. John Smith
# 	Patient: Grace Red
# 	Specialization: Dermatology
# 	Location: Houston
# ---------------------------------
# Creating healthcare provider node...
# - Provider: Dr. Sarah Johnson
# - Bio: Dr. Sarah Johnson is a pediatrician known for her compassionate care.
# Creating patient node...
# - Patient: David Black
# - Age: 93
# - Gender: Male
# - Condition: Rosacea
# Creating specialization node...
# - Specialization: Dermatology
# Creating location node...
# - Location: Los Angeles
# ---- Creating relationships ----
# 	Provider: Dr. Sarah Johnson
# 	Patient: David Black
# 	Specialization: Dermatology
# 	Location: Los Angeles
# ---------------------------------
# Creating healthcare provider node...
# - Provider: Dr. John Smith
# - Bio: Dr. John Smith is a renowned cardiologist with over 20 years of experience.
# Creating patient node...
# - Patient: Alice Brown
# - Age: 39
# - Gender: Male
# - Condition: Osteoporosis
# Creating specialization node...
# - Specialization: Orthopedics
# Creating location node...
# - Location: Los Angeles
# ---- Creating relationships ----
# 	Provider: Dr. John Smith
# 	Patient: Alice Brown
# 	Specialization: Orthopedics
# 	Location: Los Angeles
# ---------------------------------
# Creating healthcare provider node...
# - Provider: Dr. Emily Davis
# - Bio: Dr. Emily Davis specializes in neurology and has published numerous research papers.
# Creating patient node...
# - Patient: Eva Blue
# - Age: 68
# - Gender: Male
# - Condition: Parkinson's Disease
# Creating specialization node...
# - Specialization: Neurology
# Creating location node...
# - Location: Phoenix
# ---- Creating relationships ----
# 	Provider: Dr. Emily Davis
# 	Patient: Eva Blue
# 	Specialization: Neurology
# 	Location: Phoenix
# ---------------------------------
# Creating healthcare provider node...
# - Provider: Dr. Sarah Johnson
# - Bio: Dr. Sarah Johnson is a pediatrician known for her compassionate care.
# Creating patient node...
# - Patient: Alice Brown
# - Age: 35
# - Gender: Female
# - Condition: Asthma
# Creating specialization node...
# - Specialization: Pediatrics
# Creating location node...
# - Location: Los Angeles
# ---- Creating relationships ----
# 	Provider: Dr. Sarah Johnson
# 	Patient: Alice Brown
# 	Specialization: Pediatrics
# 	Location: Los Angeles
# ---------------------------------
# Creating healthcare provider node...
# - Provider: Dr. Sarah Johnson
# - Bio: Dr. Sarah Johnson is a pediatrician known for her compassionate care.
# Creating patient node...
# - Patient: David Black
# - Age: 63
# - Gender: Male
# - Condition: Parkinson's Disease
# Creating specialization node...
# - Specialization: Neurology
# Creating location node...
# - Location: Phoenix
# ---- Creating relationships ----
# 	Provider: Dr. Sarah Johnson
# 	Patient: David Black
# 	Specialization: Neurology
# 	Location: Phoenix
# ---------------------------------
# Creating healthcare provider node...
# - Provider: Dr. Emily Davis
# - Bio: Dr. Emily Davis specializes in neurology and has published numerous research papers.
# Creating patient node...
# - Patient: Grace Red
# - Age: 1
# - Gender: Female
# - Condition: Acne
# Creating specialization node...
# - Specialization: Dermatology
# Creating location node...
# - Location: Houston
# ---- Creating relationships ----
# 	Provider: Dr. Emily Davis
# 	Patient: Grace Red
# 	Specialization: Dermatology
# 	Location: Houston
# ---------------------------------
# Creating healthcare provider node...
# - Provider: Dr. Emily Davis
# - Bio: Dr. Emily Davis specializes in neurology and has published numerous research papers.
# Creating patient node...
# - Patient: Frank Yellow
# - Age: 16
# - Gender: Male
# - Condition: Rosacea
# Creating specialization node...
# - Specialization: Dermatology
# Creating location node...
# - Location: Chicago
# ---- Creating relationships ----
# 	Provider: Dr. Emily Davis
# 	Patient: Frank Yellow
# 	Specialization: Dermatology
# 	Location: Chicago
# ---------------------------------
# Creating healthcare provider node...
# - Provider: Dr. Jessica Lee
# - Bio: Dr. Jessica Lee is a dermatologist focused on skin cancer treatment and prevention.
# Creating patient node...
# - Patient: David Black
# - Age: 5
# - Gender: Male
# - Condition: Scoliosis
# Creating specialization node...
# - Specialization: Orthopedics
# Creating location node...
# - Location: Chicago
# ---- Creating relationships ----
# 	Provider: Dr. Jessica Lee
# 	Patient: David Black
# 	Specialization: Orthopedics
# 	Location: Chicago
# ---------------------------------
# Creating healthcare provider node...
# - Provider: Dr. John Smith
# - Bio: Dr. John Smith is a renowned cardiologist with over 20 years of experience.
# Creating patient node...
# - Patient: Charlie Green
# - Age: 51
# - Gender: Female
# - Condition: Eczema
# Creating specialization node...
# - Specialization: Dermatology
# Creating location node...
# - Location: Phoenix
# ---- Creating relationships ----
# 	Provider: Dr. John Smith
# 	Patient: Charlie Green
# 	Specialization: Dermatology
# 	Location: Phoenix
# ---------------------------------
# Creating healthcare provider node...
# - Provider: Dr. Emily Davis
# - Bio: Dr. Emily Davis specializes in neurology and has published numerous research papers.
# Creating patient node...
# - Patient: Frank Yellow
# - Age: 47
# - Gender: Male
# - Condition: Stroke
# Creating specialization node...
# - Specialization: Neurology
# Creating location node...
# - Location: Los Angeles
# ---- Creating relationships ----
# 	Provider: Dr. Emily Davis
# 	Patient: Frank Yellow
# 	Specialization: Neurology
# 	Location: Los Angeles
# ---------------------------------
# Creating healthcare provider node...
# - Provider: Dr. Sarah Johnson
# - Bio: Dr. Sarah Johnson is a pediatrician known for her compassionate care.
# Creating patient node...
# - Patient: Frank Yellow
# - Age: 81
# - Gender: Female
# - Condition: Epilepsy
# Creating specialization node...
# - Specialization: Neurology
# Creating location node...
# - Location: Houston
# ---- Creating relationships ----
# 	Provider: Dr. Sarah Johnson
# 	Patient: Frank Yellow
# 	Specialization: Neurology
# 	Location: Houston
# ---------------------------------
# Creating healthcare provider node...
# - Provider: Dr. John Smith
# - Bio: Dr. John Smith is a renowned cardiologist with over 20 years of experience.
# Creating patient node...
# - Patient: Grace Red
# - Age: 56
# - Gender: Male
# - Condition: Stroke
# Creating specialization node...
# - Specialization: Neurology
# Creating location node...
# - Location: Chicago
# ---- Creating relationships ----
# 	Provider: Dr. John Smith
# 	Patient: Grace Red
# 	Specialization: Neurology
# 	Location: Chicago
# ---------------------------------
# Creating healthcare provider node...
# - Provider: Dr. Sarah Johnson
# - Bio: Dr. Sarah Johnson is a pediatrician known for her compassionate care.
# Creating patient node...
# - Patient: Charlie Green
# - Age: 7
# - Gender: Male
# - Condition: ADHD
# Creating specialization node...
# - Specialization: Pediatrics
# Creating location node...
# - Location: Chicago
# ---- Creating relationships ----
# 	Provider: Dr. Sarah Johnson
# 	Patient: Charlie Green
# 	Specialization: Pediatrics
# 	Location: Chicago
# ---------------------------------
# Creating healthcare provider node...
# - Provider: Dr. Jessica Lee
# - Bio: Dr. Jessica Lee is a dermatologist focused on skin cancer treatment and prevention.
# Creating patient node...
# - Patient: Frank Yellow
# - Age: 27
# - Gender: Female
# - Condition: Heart Disease
# Creating specialization node...
# - Specialization: Cardiology
# Creating location node...
# - Location: New York
# ---- Creating relationships ----
# 	Provider: Dr. Jessica Lee
# 	Patient: Frank Yellow
# 	Specialization: Cardiology
# 	Location: New York
# ---------------------------------
# Creating healthcare provider node...
# - Provider: Dr. John Smith
# - Bio: Dr. John Smith is a renowned cardiologist with over 20 years of experience.
# Creating patient node...
# - Patient: Alice Brown
# - Age: 72
# - Gender: Female
# - Condition: Eczema
# Creating specialization node...
# - Specialization: Dermatology
# Creating location node...
# - Location: Chicago
# ---- Creating relationships ----
# 	Provider: Dr. John Smith
# 	Patient: Alice Brown
# 	Specialization: Dermatology
# 	Location: Chicago
# ---------------------------------
# Creating healthcare provider node...
# - Provider: Dr. Jessica Lee
# - Bio: Dr. Jessica Lee is a dermatologist focused on skin cancer treatment and prevention.
# Creating patient node...
# - Patient: Eva Blue
# - Age: 37
# - Gender: Male
# - Condition: Psoriasis
# Creating specialization node...
# - Specialization: Dermatology
# Creating location node...
# - Location: Phoenix
# ---- Creating relationships ----
# 	Provider: Dr. Jessica Lee
# 	Patient: Eva Blue
# 	Specialization: Dermatology
# 	Location: Phoenix
# ---------------------------------
# Creating healthcare provider node...
# - Provider: Dr. Jessica Lee
# - Bio: Dr. Jessica Lee is a dermatologist focused on skin cancer treatment and prevention.
# Creating patient node...
# - Patient: Eva Blue
# - Age: 32
# - Gender: Female
# - Condition: Epilepsy
# Creating specialization node...
# - Specialization: Neurology
# Creating location node...
# - Location: Phoenix
# ---- Creating relationships ----
# 	Provider: Dr. Jessica Lee
# 	Patient: Eva Blue
# 	Specialization: Neurology
# 	Location: Phoenix
# ---------------------------------
# Creating healthcare provider node...
# - Provider: Dr. Jessica Lee
# - Bio: Dr. Jessica Lee is a dermatologist focused on skin cancer treatment and prevention.
# Creating patient node...
# - Patient: Grace Red
# - Age: 87
# - Gender: Male
# - Condition: Fracture
# Creating specialization node...
# - Specialization: Orthopedics
# Creating location node...
# - Location: Los Angeles
# ---- Creating relationships ----
# 	Provider: Dr. Jessica Lee
# 	Patient: Grace Red
# 	Specialization: Orthopedics
# 	Location: Los Angeles
# ---------------------------------
# Creating healthcare provider node...
# - Provider: Dr. John Smith
# - Bio: Dr. John Smith is a renowned cardiologist with over 20 years of experience.
# Creating patient node...
# - Patient: Eva Blue
# - Age: 85
# - Gender: Female
# - Condition: Stroke
# Creating specialization node...
# - Specialization: Neurology
# Creating location node...
# - Location: Phoenix
# ---- Creating relationships ----
# 	Provider: Dr. John Smith
# 	Patient: Eva Blue
# 	Specialization: Neurology
# 	Location: Phoenix
# ---------------------------------
# Creating healthcare provider node...
# - Provider: Dr. Jessica Lee
# - Bio: Dr. Jessica Lee is a dermatologist focused on skin cancer treatment and prevention.
# Creating patient node...
# - Patient: Eva Blue
# - Age: 56
# - Gender: Male
# - Condition: Asthma
# Creating specialization node...
# - Specialization: Pediatrics
# Creating location node...
# - Location: Chicago
# ---- Creating relationships ----
# 	Provider: Dr. Jessica Lee
# 	Patient: Eva Blue
# 	Specialization: Pediatrics
# 	Location: Chicago
# ---------------------------------
# Creating healthcare provider node...
# - Provider: Dr. Jessica Lee
# - Bio: Dr. Jessica Lee is a dermatologist focused on skin cancer treatment and prevention.
# Creating patient node...
# - Patient: Bob White
# - Age: 46
# - Gender: Male
# - Condition: Migraine
# Creating specialization node...
# - Specialization: Neurology
# Creating location node...
# - Location: Houston
# ---- Creating relationships ----
# 	Provider: Dr. Jessica Lee
# 	Patient: Bob White
# 	Specialization: Neurology
# 	Location: Houston
# ---------------------------------
# Creating healthcare provider node...
# - Provider: Dr. John Smith
# - Bio: Dr. John Smith is a renowned cardiologist with over 20 years of experience.
# Creating patient node...
# - Patient: David Black
# - Age: 69
# - Gender: Female
# - Condition: Fracture
# Creating specialization node...
# - Specialization: Orthopedics
# Creating location node...
# - Location: Phoenix
# ---- Creating relationships ----
# 	Provider: Dr. John Smith
# 	Patient: David Black
# 	Specialization: Orthopedics
# 	Location: Phoenix
# ---------------------------------
# Creating healthcare provider node...
# - Provider: Dr. Emily Davis
# - Bio: Dr. Emily Davis specializes in neurology and has published numerous research papers.
# Creating patient node...
# - Patient: Frank Yellow
# - Age: 77
# - Gender: Male
# - Condition: Rosacea
# Creating specialization node...
# - Specialization: Dermatology
# Creating location node...
# - Location: Los Angeles
# ---- Creating relationships ----
# 	Provider: Dr. Emily Davis
# 	Patient: Frank Yellow
# 	Specialization: Dermatology
# 	Location: Los Angeles
# ---------------------------------
# Creating healthcare provider node...
# - Provider: Dr. Emily Davis
# - Bio: Dr. Emily Davis specializes in neurology and has published numerous research papers.
# Creating patient node...
# - Patient: Bob White
# - Age: 53
# - Gender: Male
# - Condition: Parkinson's Disease
# Creating specialization node...
# - Specialization: Neurology
# Creating location node...
# - Location: Los Angeles
# ---- Creating relationships ----
# 	Provider: Dr. Emily Davis
# 	Patient: Bob White
# 	Specialization: Neurology
# 	Location: Los Angeles
# ---------------------------------
# Creating healthcare provider node...
# - Provider: Dr. Sarah Johnson
# - Bio: Dr. Sarah Johnson is a pediatrician known for her compassionate care.
# Creating patient node...
# - Patient: Charlie Green
# - Age: 97
# - Gender: Male
# - Condition: Acne
# Creating specialization node...
# - Specialization: Dermatology
# Creating location node...
# - Location: Phoenix
# ---- Creating relationships ----
# 	Provider: Dr. Sarah Johnson
# 	Patient: Charlie Green
# 	Specialization: Dermatology
# 	Location: Phoenix
# ---------------------------------
# Creating healthcare provider node...
# - Provider: Dr. Sarah Johnson
# - Bio: Dr. Sarah Johnson is a pediatrician known for her compassionate care.
# Creating patient node...
# - Patient: Grace Red
# - Age: 88
# - Gender: Male
# - Condition: Osteoporosis
# Creating specialization node...
# - Specialization: Orthopedics
# Creating location node...
# - Location: Los Angeles
# ---- Creating relationships ----
# 	Provider: Dr. Sarah Johnson
# 	Patient: Grace Red
# 	Specialization: Orthopedics
# 	Location: Los Angeles
# ---------------------------------
# Creating healthcare provider node...
# - Provider: Dr. John Smith
# - Bio: Dr. John Smith is a renowned cardiologist with over 20 years of experience.
# Creating patient node...
# - Patient: Grace Red
# - Age: 13
# - Gender: Female
# - Condition: Heart Disease
# Creating specialization node...
# - Specialization: Cardiology
# Creating location node...
# - Location: Phoenix
# ---- Creating relationships ----
# 	Provider: Dr. John Smith
# 	Patient: Grace Red
# 	Specialization: Cardiology
# 	Location: Phoenix
# ---------------------------------
# Creating healthcare provider node...
# - Provider: Dr. John Smith
# - Bio: Dr. John Smith is a renowned cardiologist with over 20 years of experience.
# Creating patient node...
# - Patient: Charlie Green
# - Age: 56
# - Gender: Female
# - Condition: Fracture
# Creating specialization node...
# - Specialization: Orthopedics
# Creating location node...
# - Location: Phoenix
# ---- Creating relationships ----
# 	Provider: Dr. John Smith
# 	Patient: Charlie Green
# 	Specialization: Orthopedics
# 	Location: Phoenix
# ---------------------------------
# Creating healthcare provider node...
# - Provider: Dr. Michael Brown
# - Bio: Dr. Michael Brown is an orthopedic surgeon with expertise in joint replacement.
# Creating patient node...
# - Patient: Charlie Green
# - Age: 95
# - Gender: Male
# - Condition: Parkinson's Disease
# Creating specialization node...
# - Specialization: Neurology
# Creating location node...
# - Location: Houston
# ---- Creating relationships ----
# 	Provider: Dr. Michael Brown
# 	Patient: Charlie Green
# 	Specialization: Neurology
# 	Location: Houston
# ---------------------------------
# Creating healthcare provider node...
# - Provider: Dr. Sarah Johnson
# - Bio: Dr. Sarah Johnson is a pediatrician known for her compassionate care.
# Creating patient node...
# - Patient: David Black
# - Age: 63
# - Gender: Male
# - Condition: Coronary Artery Disease
# Creating specialization node...
# - Specialization: Cardiology
# Creating location node...
# - Location: Chicago
# ---- Creating relationships ----
# 	Provider: Dr. Sarah Johnson
# 	Patient: David Black
# 	Specialization: Cardiology
# 	Location: Chicago
# ---------------------------------
# Finished populating graph!

# %%
from langchain_openai import ChatOpenAI

OPENAI_API_KEY = os.getenv('OPENAI_API_KEY')
OPENAI_EMBEDDINGS_ENDPOINT = os.getenv('OPENAI_EMBEDDINGS_ENDPOINT')

llm = ChatOpenAI(api_key=OPENAI_API_KEY)

# %%
from langchain_community.graphs import Neo4jGraph

# Create knowledge graph
kg = Neo4jGraph(
    url=NEO4J_URI,
    username=NEO4J_USERNAME,
    password=NEO4J_PASSWORD,
)

# Note: May need to install APOC plugin for Neo4j Desktop (enterprise version)
# Out:
# /var/folders/fl/gms0qrfn1vb9675l1rjr6x2r0000gn/T/ipykernel_38211/3618560195.py:4: LangChainDeprecationWarning: The class `Neo4jGraph` was deprecated in LangChain 0.3.8 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-neo4j package and should be used instead. To use it run `pip install -U :class:`~langchain-neo4j` and import as `from :class:`~langchain_neo4j import Neo4jGraph``.
#   kg = Neo4jGraph(

# %%
# Create vector index
kg.query(
    '''
    CREATE VECTOR INDEX health_providers_embeddings IF NOT EXISTS
    FOR (hp:HealthcareProvider) ON (hp.comprehensiveEmbedding)
    OPTIONS {
      indexConfig: {
        `vector.dimensions`: 1536,
        `vector.similarity_function`: 'cosine'
      }
    }
    '''
)
# Out:
# []

# %%
print(kg.query('SHOW VECTOR INDEXES'))
# Out:
# [{'id': 2, 'name': 'health_providers_embeddings', 'state': 'ONLINE', 'populationPercent': 100.0, 'type': 'VECTOR', 'entityType': 'NODE', 'labelsOrTypes': ['HealthcareProvider'], 'properties': ['comprehensiveEmbedding'], 'indexProvider': 'vector-2.0', 'owningConstraint': None, 'lastRead': None, 'readCount': 0}]

# %%
# Embedding bio field in every healthcare provider node
kg.query(
    '''
    MATCH (hp:HealthcareProvider)-[:TREATS]->(p:Patient)
    WHERE hp.bio IS NOT NULL
    WITH hp, genai.vector.encode(
        hp.bio,
        "OpenAI",
        {
          token: $openAiApiKey,
          endpoint: $openAiEmbeddingsEndpoint
        }) AS vector
    WITH hp, vector
    WHERE vector IS NOT NULL
    CALL db.create.setNodeVectorProperty(hp, "comprehensiveEmbedding", vector)
    ''',
    params={
        'openAiApiKey': OPENAI_API_KEY,
        'openAiEmbeddingsEndpoint': OPENAI_EMBEDDINGS_ENDPOINT,
    },
)

# Note: genai.vector.encode for Neo4j Desktop (enterprise version) is activate by:
# Move or copy the genai plugins (.jar files) from <NEO4J_HOME>/products 
# to the <NEO4J_HOME>/plugins directory
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# Cell In[11], line 2
#       1 # Embedding bio field in every healthcare provider node
# ----> 2 kg.query(
#       3     '''
#       4     MATCH (hp:HealthcareProvider)-[:TREATS]->(p:Patient)
#       5     WHERE hp.bio IS NOT NULL
#       6     WITH hp, genai.vector.encode(
#       7         hp.bio,
#       8         "OpenAI",
#       9         {
#      10           token: $openAiApiKey,
#      11           endpoint: $openAiEmbeddingsEndpoint
#      12         }) AS vector
#      13     WITH hp, vector
#      14     WHERE vector IS NOT NULL
#      15     CALL db.create.setNodeVectorProperty(hp, "comprehensiveEmbedding", vector)
#      16     ''',
#      17     params={
#      18         'openAiApiKey': OPENAI_API_KEY,
#      19         'openAiEmbeddingsEndpoint': OPENAI_EMBEDDINGS_ENDPOINT,
#      20     },
#      21 )
#      23 # Note: genai.vector.encode for Neo4j Desktop (enterprise version) is activate by:
#      24 # Move or copy the genai plugins (.jar files) from <NEO4J_HOME>/products
#      25 # to the <NEO4J_HOME>/plugins directory
#
# File ~/Desktop/Project/1.in-progress/rag/graph-rag/.venv/lib/python3.10/site-packages/langchain_community/graphs/neo4j_graph.py:467, in Neo4jGraph.query(self, query, params)
#     464 from neo4j.exceptions import Neo4jError
#     466 try:
# --> 467     data, _, _ = self._driver.execute_query(
#     468         Query(text=query, timeout=self.timeout),
#     469         database_=self._database,
#     470         parameters_=params,
#     471     )
#     472     json_data = [r.data() for r in data]
#     473     if self.sanitize:
#
# File ~/Desktop/Project/1.in-progress/rag/graph-rag/.venv/lib/python3.10/site-packages/neo4j/_sync/driver.py:970, in Driver.execute_query(self, query_, parameters_, routing_, database_, impersonated_user_, bookmark_manager_, auth_, result_transformer_, **kwargs)
#     966     raise ValueError(
#     967         f"Invalid routing control value: {routing_!r}"
#     968     )
#     969 with session._pipelined_begin:
# --> 970     return session._run_transaction(
#     971         access_mode,
#     972         TelemetryAPI.DRIVER,
#     973         work,
#     974         (query_str, parameters, result_transformer_),
#     975         {},
#     976     )
#
# File ~/Desktop/Project/1.in-progress/rag/graph-rag/.venv/lib/python3.10/site-packages/neo4j/_sync/work/session.py:583, in Session._run_transaction(self, access_mode, api, transaction_function, args, kwargs)
#     581 tx = self._transaction
#     582 try:
# --> 583     result = transaction_function(tx, *args, **kwargs)
#     584 except asyncio.CancelledError:
#     585     # if cancellation callback has not been called yet:
#     586     if self._transaction is not None:
#
# File ~/Desktop/Project/1.in-progress/rag/graph-rag/.venv/lib/python3.10/site-packages/neo4j/_work/query.py:144, in unit_of_work.<locals>.wrapper.<locals>.wrapped(*args, **kwargs)
#     143 def wrapped(*args, **kwargs):
# --> 144     return f(*args, **kwargs)
#
# File ~/Desktop/Project/1.in-progress/rag/graph-rag/.venv/lib/python3.10/site-packages/neo4j/_sync/driver.py:1306, in _work(tx, query, parameters, transformer)
#    1300 def _work(
#    1301     tx: ManagedTransaction,
#    1302     query: te.LiteralString,
#    1303     parameters: dict[str, t.Any],
#    1304     transformer: t.Callable[[Result], t.Union[_T]],
#    1305 ) -> _T:
# -> 1306     res = tx.run(query, parameters)
#    1307     return transformer(res)
#
# File ~/Desktop/Project/1.in-progress/rag/graph-rag/.venv/lib/python3.10/site-packages/neo4j/_sync/work/transaction.py:206, in TransactionBase.run(self, query, parameters, **kwparameters)
#     203 self._results.append(result)
#     205 parameters = dict(parameters or {}, **kwparameters)
# --> 206 result._tx_ready_run(query, parameters)
#     208 return result
#
# File ~/Desktop/Project/1.in-progress/rag/graph-rag/.venv/lib/python3.10/site-packages/neo4j/_sync/work/result.py:177, in Result._tx_ready_run(self, query, parameters)
#     173 def _tx_ready_run(self, query, parameters):
#     174     # BEGIN+RUN does not carry any extra on the RUN message.
#     175     # BEGIN {extra}
#     176     # RUN "query" {parameters} {extra}
# --> 177     self._run(query, parameters, None, None, None, None, None, None)
#
# File ~/Desktop/Project/1.in-progress/rag/graph-rag/.venv/lib/python3.10/site-packages/neo4j/_sync/work/result.py:236, in Result._run(self, query, parameters, db, imp_user, access_mode, bookmarks, notifications_min_severity, notifications_disabled_classifications)
#     234 self._pull()
#     235 self._connection.send_all()
# --> 236 self._attach()
#
# File ~/Desktop/Project/1.in-progress/rag/graph-rag/.venv/lib/python3.10/site-packages/neo4j/_sync/work/result.py:430, in Result._attach(self)
#     428 if self._exhausted is False:
#     429     while self._attached is False:
# --> 430         self._connection.fetch_message()
#
# File ~/Desktop/Project/1.in-progress/rag/graph-rag/.venv/lib/python3.10/site-packages/neo4j/_sync/io/_common.py:184, in ConnectionErrorHandler.__getattr__.<locals>.outer.<locals>.inner(*args, **kwargs)
#     182 def inner(*args, **kwargs):
#     183     try:
# --> 184         func(*args, **kwargs)
#     185     except (Neo4jError, ServiceUnavailable, SessionExpired) as exc:
#     186         assert not asyncio.iscoroutinefunction(self.__on_error)
#
# File ~/Desktop/Project/1.in-progress/rag/graph-rag/.venv/lib/python3.10/site-packages/neo4j/_sync/io/_bolt.py:864, in Bolt.fetch_message(self)
#     860 # Receive exactly one message
#     861 tag, fields = self.inbox.pop(
#     862     hydration_hooks=self.responses[0].hydration_hooks
#     863 )
# --> 864 res = self._process_message(tag, fields)
#     865 self.idle_since = monotonic()
#     866 return res
#
# File ~/Desktop/Project/1.in-progress/rag/graph-rag/.venv/lib/python3.10/site-packages/neo4j/_sync/io/_bolt5.py:1208, in Bolt5x7._process_message(self, tag, fields)
#    1206 self._enrich_error_diagnostic_record(summary_metadata)
#    1207 try:
# -> 1208     response.on_failure(summary_metadata or {})
#    1209 except (ServiceUnavailable, DatabaseUnavailable):
#    1210     if self.pool:
#
# File ~/Desktop/Project/1.in-progress/rag/graph-rag/.venv/lib/python3.10/site-packages/neo4j/_sync/io/_common.py:254, in Response.on_failure(self, metadata)
#     252 handler = self.handlers.get("on_summary")
#     253 Util.callback(handler)
# --> 254 raise self._hydrate_error(metadata)
#
# ClientError: {code: Neo.ClientError.Procedure.ProcedureCallFailed} {message: Failed to invoke function `genai.vector.encode`: Caused by: org.neo4j.genai.vector.MalformedGenAIResponseException: Unexpected HTTP response code: 504 Gateway Time-out - error code: 504}

# %%
# Test if embedding is created successfully
result = kg.query('''
    MATCH (hp:HealthcareProvider)
    WHERE hp.bio IS NOT NULL
    RETURN hp.bio, hp.name, hp.comprehensiveEmbedding
    LIMIT 5
''')

for record in result:
    print(f"Name: {record['hp.name']}")
    print(f"Bio: {record['hp.bio']}")
    print(f"Embedding: {record['hp.comprehensiveEmbedding']}")
    print("---")
# Out:
# Name: Dr. Jessica Lee
# Bio: Dr. Jessica Lee is a dermatologist focused on skin cancer treatment and prevention.
# Embedding: [-0.001317372894845903, 0.006131031550467014, 0.016967637464404106, -0.018396228551864624, -0.016503972932696342, 0.008903623558580875, -0.0060464441776275635, 0.008239454589784145, 0.005068987607955933, -0.0017606744077056646, 0.0007620712276548147, 0.004060202743858099, 0.0011709111277014017, -0.0006704347324557602, -0.013521477580070496, 0.011409921571612358, 0.028872553259134293, -0.021905044093728065, 0.002099024597555399, -0.011792132630944252, -0.026165751740336418, -0.010269556194543839, -0.012337252497673035, -0.004683644510805607, 0.002808620221912861, 0.009191848337650299, 0.0005854555638507009, -0.020000258460640907, -0.005526387132704258, 0.013183128088712692, 0.010576577857136726, 0.008214391767978668, -0.0038941605016
0.0072411405853927135, -0.005152835976332426, 0.01010979525744915, 0.0005998741835355759, -0.00687466049566865, 0.0202195905148983, -0.014722389169037342, 0.006596641149371862, 0.016908632591366768, 0.03389308601617813, 0.019714100286364555, 0.005828928668051958, -0.004321937449276447, 0.02691732905805111, -0.013521851040422916, 0.028711818158626556, 0.022961871698498726, -0.018854767084121704, -0.01563226990401745, 0.028332700952887535, 0.009073540568351746, -0.011367200873792171, -0.024389879778027534, -0.013344929553568363, -0.008624918758869171, 0.01386305596679449, 0.01856411062180996, -0.01601138710975647, -0.00893453136086464, 0.020472334697842598, -0.014722389169037342, -0.019183335825800896, -0.000740858435165137, -0.010716382414102554, -0.010387814603745937, 0.00798041932284832, -0.020927274599671364, -0.0180333461612463, 0.02830742672085762, 0.003601614385843277, 0.023758018389344215, -0.020080579444766045, 0.003601614385843277, 0.0044483100064098835, -0.026993151754140854, -0.021003099158406258, -0.017148740589618683, -0.008574370294809341, -0.002009321702644229, -0.003418374340981245, 0.015152054838836193, 0.0025590418372303247, -0.0077087185345590115, 0.019056962803006172, -0.026942603290081024, 0.019701462239027023, -0.01963827759027481, 0.000331727642333135, -0.0012439786223694682, 0.01776796393096447, -0.0020124809816479683, 0.008549095131456852, 0.01186637207865715, 0.003655322827398777, 0.010476275347173214, 0.0032019615173339844, 0.0032509309239685535, 0.015771280974149704, 0.014419094659388065, 0.005468767136335373, 0.0006211994914337993, 0.003999687731266022, 0.003528950270265341, 0.015303702093660831, -0.00018067308701574802, 0.007152679841965437, -0.013054273091256618, -0.015581721439957619, -0.01149357296526432, 0.003028199542313814, -0.009414746426045895, 0.004625231027603149, 0.006189090199768543, 0.013395478017628193, -0.026159094646573067, 0.0017170854844152927, -0.01750258170068264, 0.009901280514895916, -0.0017960682744160295, 0.0395798459649086, -0.026083270087838173, 0.005948982667177916, -0.023821204900741577, 0.0034152150619775057, -0.026538211852312088, -0.01663061231374 ...
# ---

# %%
# Query
question = 'Give me a list of healthcare providers whose speciality is Cardiology'

# Embedding the question and retrieve from knowledge graph
result = kg.query(
    '''
    WITH genai.vector.encode(
        $question,
        "OpenAI",
        {
          token: $openAiApiKey,
          endpoint: $openAiEndpoint
        }) AS question_embedding
    CALL db.index.vector.queryNodes(
        'health_providers_embeddings',
        $top_k,
        question_embedding
        ) YIELD node AS healthcare_provider, score
    RETURN healthcare_provider.name, healthcare_provider.bio, score
    ''',
    params={
        'openAiApiKey': OPENAI_API_KEY,
        'openAiEndpoint': OPENAI_EMBEDDINGS_ENDPOINT,
        'question': question,
        'top_k': 3,
    },
)

for record in result:
    print('Name:', record['healthcare_provider.name'])
    print('Bio:', record['healthcare_provider.bio'])
    print('Score:', record['score'])
    print('---')
# Out:
# Name: Dr. John Smith
# Bio: Dr. John Smith is a renowned cardiologist with over 20 years of experience.
# Score: 0.9129180908203125
# ---
# Name: Dr. Sarah Johnson
# Bio: Dr. Sarah Johnson is a pediatrician known for her compassionate care.
# Score: 0.8825836181640625
# ---
# Name: Dr. Emily Davis
# Bio: Dr. Emily Davis specializes in neurology and has published numerous research papers.
# Score: 0.877777099609375
# ---
